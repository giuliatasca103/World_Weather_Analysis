# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import gmaps
import requests
# Import the API key.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. so that it doesn't generate random numbers every time
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 772

# %%
from config import weather_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# %%
city_d = list()

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

#city_weather = requests.get(city_url).json()
#city_weather

    try:
        city_w = requests.get(city_url).json()
        city_name = city
        city_lat = city_w['coord']['lat']
        city_lng = city_w['coord']['lon']
        city_max_temp = city_w['main']['temp_max']
        city_humid = city_w['main']['humidity']
        city_cloud = city_w['clouds']['all']
        city_speed = city_w['wind']['speed']
        city_country = city_w['sys']['country']
        city_weather_desc = city_w['weather'][0]['description']
        city_d.append({"City": city_name,
                       "Country": city_country,
                       "Lat": city_lat,
                       "Lng": city_lng,
                       "Max Temp": city_max_temp,
                       "Humidity": city_humid,
                       "Cloudiness": city_cloud,
                       "Wind Speed": city_speed,
                       "Current Description": city_weather_desc})
        
    
    except:
        print("City not found. Skipping...")
        pass
    
print("---------------------")
print("Data Retrieval Complete")
print("---------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | namibe
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | fairbanks
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | dien bien
# City not found. Skipping...
# Processing Record 8 of Set 1 | marathon
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | bambous virieux
# Processing Record 11 of Set 1 | sinnamary
# Processing Record 12 of Set 1 | jiwani
# Processing Record 13 of Set 1 | dalby
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | ketchikan
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | great falls
# Processing Record 20 of Set 1 | codrington
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | sao joao da barra
# Processing Record 23 of Set 1 | pyaozerskiy
# Processing Record 24 of Set 1 | hasaki
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | maroantsetra
# Processing Record 27 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | naron
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | sijunjung
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | san luis
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | dedza
# Processing Record 43 of Set 1 | peniche
# Processing Record 44 of Set 1 | brekstad
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | harindanga
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | xai-xai
# Processing Record 1 of Set 2 | kenai
# Processing Record 2 of Set 2 | singarayakonda
# Processing Record 3 of Set 2 | whitehorse
# Processing Record 4 of Set 2 | alofi
# Processing Record 5 of Set 2 | manggar
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | narsaq
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 2 | nongstoin
# Processing Record 10 of Set 2 | dancheng
# Processing Record 11 of Set 2 | stromness
# Processing Record 12 of Set 2 | huilong
# Processing Record 13 of Set 2 | asyut
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | viedma
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | pemangkat
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | luena
# Processing Record 20 of Set 2 | buraydah
# Processing Record 21 of Set 2 | harer
# Processing Record 22 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 2 | cochrane
# Processing Record 24 of Set 2 | la seyne-sur-mer
# Processing Record 25 of Set 2 | orthez
# Processing Record 26 of Set 2 | lavrentiya
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | ushuaia
# Processing Record 29 of Set 2 | priladozhskiy
# Processing Record 30 of Set 2 | tiksi
# Processing Record 31 of Set 2 | lasa
# Processing Record 32 of Set 2 | sunland park
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | clyde river
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | quatre cocos
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | rocky mountain house
# Processing Record 41 of Set 2 | deer lake
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | sitka
# Processing Record 44 of Set 2 | bandarbeyla
# Processing Record 45 of Set 2 | jacmel
# Processing Record 46 of Set 2 | ucluelet
# Processing Record 47 of Set 2 | busselton
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | dorado
# Processing Record 50 of Set 2 | san jose
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | black river
# Processing Record 3 of Set 3 | ylivieska
# Processing Record 4 of Set 3 | severo-kurilsk
# Processing Record 5 of Set 3 | batuan
# Processing Record 6 of Set 3 | baturaja
# Processing Record 7 of Set 3 | taonan
# Processing Record 8 of Set 3 | omboue
# Processing Record 9 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | okakarara
# Processing Record 12 of Set 3 | la ronge
# Processing Record 13 of Set 3 | warrnambool
# Processing Record 14 of Set 3 | vestmannaeyjar
# Processing Record 15 of Set 3 | hammerfest
# Processing Record 16 of Set 3 | grindavik
# Processing Record 17 of Set 3 | vernon
# Processing Record 18 of Set 3 | aklavik
# Processing Record 19 of Set 3 | nanortalik
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | shelburne
# Processing Record 22 of Set 3 | portland
# Processing Record 23 of Set 3 | hovd
# Processing Record 24 of Set 3 | acapulco
# Processing Record 25 of Set 3 | shingu
# Processing Record 26 of Set 3 | yeehaw junction
# City not found. Skipping...
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | lalitpur
# Processing Record 29 of Set 3 | kutum
# Processing Record 30 of Set 3 | meulaboh
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | north bend
# Processing Record 33 of Set 3 | alice springs
# Processing Record 34 of Set 3 | tasiilaq
# Processing Record 35 of Set 3 | hue
# Processing Record 36 of Set 3 | daman
# Processing Record 37 of Set 3 | krutikha
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | encruzilhada do sul
# Processing Record 41 of Set 3 | gat
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | kieta
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | ancud
# Processing Record 46 of Set 3 | rahuri
# Processing Record 47 of Set 3 | benguela
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 50 of Set 3 | san patricio
# Processing Record 1 of Set 4 | mirnyy
# Processing Record 2 of Set 4 | ponta do sol
# Processing Record 3 of Set 4 | newcastle
# Processing Record 4 of Set 4 | gigmoto
# Processing Record 5 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 4 | cayenne
# Processing Record 7 of Set 4 | aberystwyth
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | puerto escondido
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | svetlyy
# Processing Record 12 of Set 4 | zyryanskoye
# Processing Record 13 of Set 4 | isangel
# Processing Record 14 of Set 4 | victoria
# Processing Record 15 of Set 4 | sola
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | deputatskiy
# Processing Record 18 of Set 4 | porto-vecchio
# Processing Record 19 of Set 4 | palora
# Processing Record 20 of Set 4 | camacupa
# Processing Record 21 of Set 4 | qaqortoq
# Processing Record 22 of Set 4 | pontianak
# Processing Record 23 of Set 4 | mendi
# Processing Record 24 of Set 4 | lebu
# Processing Record 25 of Set 4 | kahului
# Processing Record 26 of Set 4 | dukat
# Processing Record 27 of Set 4 | manado
# Processing Record 28 of Set 4 | pribyslav
# Processing Record 29 of Set 4 | makakilo city
# Processing Record 30 of Set 4 | leningradskiy
# Processing Record 31 of Set 4 | wangqing
# Processing Record 32 of Set 4 | san carlos
# Processing Record 33 of Set 4 | yulara
# Processing Record 34 of Set 4 | tawzar
# City not found. Skipping...
# Processing Record 35 of Set 4 | manokwari
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | macapa
# Processing Record 38 of Set 4 | upernavik
# Processing Record 39 of Set 4 | cururupu
# Processing Record 40 of Set 4 | vanino
# Processing Record 41 of Set 4 | mountain home
# Processing Record 42 of Set 4 | pisco
# Processing Record 43 of Set 4 | hatton
# Processing Record 44 of Set 4 | katsuura
# Processing Record 45 of Set 4 | colares
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | kungurtug
# Processing Record 48 of Set 4 | saint anthony
# Processing Record 49 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 4 | kanniyakumari
# Processing Record 1 of Set 5 | dole
# Processing Record 2 of Set 5 | dikson
# Processing Record 3 of Set 5 | guerrero negro
# Processing Record 4 of Set 5 | heilbad heiligenstadt
# Processing Record 5 of Set 5 | gloucester
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | kangaatsiaq
# Processing Record 8 of Set 5 | chino valley
# Processing Record 9 of Set 5 | pitea
# Processing Record 10 of Set 5 | basoko
# Processing Record 11 of Set 5 | esperance
# Processing Record 12 of Set 5 | codajas
# Processing Record 13 of Set 5 | namtsy
# Processing Record 14 of Set 5 | skjervoy
# Processing Record 15 of Set 5 | redcliffe
# Processing Record 16 of Set 5 | borgo san dalmazzo
# Processing Record 17 of Set 5 | dingle
# Processing Record 18 of Set 5 | barcelona
# Processing Record 19 of Set 5 | elk city
# Processing Record 20 of Set 5 | anchorage
# Processing Record 21 of Set 5 | abu samrah
# Processing Record 22 of Set 5 | kosh-agach
# Processing Record 23 of Set 5 | yashkul
# Processing Record 24 of Set 5 | andenes
# Processing Record 25 of Set 5 | illela
# Processing Record 26 of Set 5 | babynino
# Processing Record 27 of Set 5 | bilibino
# Processing Record 28 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 5 | tuatapere
# Processing Record 30 of Set 5 | nioro
# Processing Record 31 of Set 5 | tengushevo
# Processing Record 32 of Set 5 | okhotsk
# Processing Record 33 of Set 5 | careiro da varzea
# Processing Record 34 of Set 5 | pafos
# Processing Record 35 of Set 5 | noshiro
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | baykit
# Processing Record 38 of Set 5 | rio gallegos
# Processing Record 39 of Set 5 | rafsanjan
# Processing Record 40 of Set 5 | salym
# Processing Record 41 of Set 5 | umm kaddadah
# Processing Record 42 of Set 5 | meridian
# Processing Record 43 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 5 | karratha
# Processing Record 45 of Set 5 | mount isa
# Processing Record 46 of Set 5 | khumalag
# Processing Record 47 of Set 5 | praia
# Processing Record 48 of Set 5 | bollnas
# Processing Record 49 of Set 5 | porbandar
# Processing Record 50 of Set 5 | ponta delgada
# Processing Record 1 of Set 6 | chernushka
# Processing Record 2 of Set 6 | mingguang
# Processing Record 3 of Set 6 | dom pedrito
# Processing Record 4 of Set 6 | haines junction
# Processing Record 5 of Set 6 | redondela
# Processing Record 6 of Set 6 | kajansi
# Processing Record 7 of Set 6 | komsomolskiy
# Processing Record 8 of Set 6 | turukhansk
# Processing Record 9 of Set 6 | gardan diwal
# City not found. Skipping...
# Processing Record 10 of Set 6 | hualmay
# Processing Record 11 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 6 | klaksvik
# Processing Record 13 of Set 6 | rabo de peixe
# Processing Record 14 of Set 6 | zalantun
# Processing Record 15 of Set 6 | bani
# Processing Record 16 of Set 6 | east london
# Processing Record 17 of Set 6 | roberto payan
# City not found. Skipping...
# Processing Record 18 of Set 6 | ostrovnoy
# Processing Record 19 of Set 6 | rawson
# Processing Record 20 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 6 | vardo
# Processing Record 22 of Set 6 | naliya
# Processing Record 23 of Set 6 | astara
# Processing Record 24 of Set 6 | srednekolymsk
# Processing Record 25 of Set 6 | pevek
# Processing Record 26 of Set 6 | saint-georges
# Processing Record 27 of Set 6 | arraial do cabo
# Processing Record 28 of Set 6 | port-cartier
# Processing Record 29 of Set 6 | le vauclin
# Processing Record 30 of Set 6 | vaida
# Processing Record 31 of Set 6 | port arthur
# Processing Record 32 of Set 6 | timmins
# Processing Record 33 of Set 6 | san lawrenz
# Processing Record 34 of Set 6 | airai
# Processing Record 35 of Set 6 | barrow
# Processing Record 36 of Set 6 | laguna
# Processing Record 37 of Set 6 | westport
# Processing Record 38 of Set 6 | biak
# Processing Record 39 of Set 6 | millerovo
# Processing Record 40 of Set 6 | santa vitoria do palmar
# Processing Record 41 of Set 6 | coolum beach
# Processing Record 42 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 6 | morant bay
# Processing Record 44 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 6 | dutlwe
# Processing Record 46 of Set 6 | henties bay
# Processing Record 47 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 6 | loreto
# Processing Record 49 of Set 6 | bonavista
# Processing Record 50 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 7 | mpongwe
# Processing Record 2 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 7 | great yarmouth
# Processing Record 4 of Set 7 | oranjemund
# Processing Record 5 of Set 7 | abbeyfeale
# Processing Record 6 of Set 7 | maldonado
# Processing Record 7 of Set 7 | loandjili
# Processing Record 8 of Set 7 | flinders
# Processing Record 9 of Set 7 | gasa
# Processing Record 10 of Set 7 | daosa
# City not found. Skipping...
# Processing Record 11 of Set 7 | maua
# Processing Record 12 of Set 7 | balgazyn
# Processing Record 13 of Set 7 | pundaguitan
# Processing Record 14 of Set 7 | santarem
# Processing Record 15 of Set 7 | paracuru
# Processing Record 16 of Set 7 | shellbrook
# Processing Record 17 of Set 7 | uyuni
# Processing Record 18 of Set 7 | erenhot
# Processing Record 19 of Set 7 | port lincoln
# Processing Record 20 of Set 7 | brae
# Processing Record 21 of Set 7 | kargasok
# Processing Record 22 of Set 7 | egvekinot
# Processing Record 23 of Set 7 | ahome
# Processing Record 24 of Set 7 | araguatins
# City not found. Skipping...
# Processing Record 25 of Set 7 | homer
# Processing Record 26 of Set 7 | hueytamalco
# Processing Record 27 of Set 7 | juegang
# Processing Record 28 of Set 7 | ballina
# Processing Record 29 of Set 7 | ossora
# Processing Record 30 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 7 | yanam
# Processing Record 32 of Set 7 | ust-ilimsk
# Processing Record 33 of Set 7 | hendek
# Processing Record 34 of Set 7 | pringsewu
# Processing Record 35 of Set 7 | melito di porto salvo
# Processing Record 36 of Set 7 | montalvo
# Processing Record 37 of Set 7 | murgab
# Processing Record 38 of Set 7 | lincoln
# Processing Record 39 of Set 7 | mapiri
# Processing Record 40 of Set 7 | grand-santi
# Processing Record 41 of Set 7 | ust-nera
# Processing Record 42 of Set 7 | kodiak
# Processing Record 43 of Set 7 | butiama
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | gela
# Processing Record 46 of Set 7 | batouri
# Processing Record 47 of Set 7 | yumen
# Processing Record 48 of Set 7 | esso
# Processing Record 49 of Set 7 | nishihara
# Processing Record 50 of Set 7 | inta
# Processing Record 1 of Set 8 | koygorodok
# Processing Record 2 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 8 | umm lajj
# Processing Record 4 of Set 8 | bilma
# Processing Record 5 of Set 8 | ondangwa
# Processing Record 6 of Set 8 | holzminden
# Processing Record 7 of Set 8 | nadvoitsy
# Processing Record 8 of Set 8 | griffith
# Processing Record 9 of Set 8 | kawalu
# Processing Record 10 of Set 8 | pangnirtung
# Processing Record 11 of Set 8 | sambava
# Processing Record 12 of Set 8 | ilabaya
# Processing Record 13 of Set 8 | saint-joseph
# Processing Record 14 of Set 8 | kokubu
# Processing Record 15 of Set 8 | pachino
# Processing Record 16 of Set 8 | tecoanapa
# Processing Record 17 of Set 8 | san cristobal
# Processing Record 18 of Set 8 | andreapol
# Processing Record 19 of Set 8 | rajpipla
# Processing Record 20 of Set 8 | gbadolite
# Processing Record 21 of Set 8 | vestmanna
# Processing Record 22 of Set 8 | sayyan
# Processing Record 23 of Set 8 | hervey bay
# Processing Record 24 of Set 8 | mahebourg
# Processing Record 25 of Set 8 | hamilton
# Processing Record 26 of Set 8 | jumla
# Processing Record 27 of Set 8 | port blair
# Processing Record 28 of Set 8 | kalaswala
# Processing Record 29 of Set 8 | birkenfeld
# Processing Record 30 of Set 8 | soe
# Processing Record 31 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 8 | aksu
# Processing Record 33 of Set 8 | rapid valley
# Processing Record 34 of Set 8 | rehlingen-siersburg
# Processing Record 35 of Set 8 | palauig
# Processing Record 36 of Set 8 | morondava
# Processing Record 37 of Set 8 | bagotville
# Processing Record 38 of Set 8 | kavaratti
# Processing Record 39 of Set 8 | ballitoville
# Processing Record 40 of Set 8 | iqaluit
# Processing Record 41 of Set 8 | burriana
# Processing Record 42 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 8 | poum
# Processing Record 44 of Set 8 | waingapu
# Processing Record 45 of Set 8 | ferrol
# Processing Record 46 of Set 8 | kamenka
# Processing Record 47 of Set 8 | roald
# Processing Record 48 of Set 8 | surovikino
# Processing Record 49 of Set 8 | vokhtoga
# Processing Record 50 of Set 8 | conceicao do araguaia
# Processing Record 1 of Set 9 | teahupoo
# Processing Record 2 of Set 9 | maltahohe
# Processing Record 3 of Set 9 | santa vitoria
# Processing Record 4 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 5 of Set 9 | chipata
# Processing Record 6 of Set 9 | catuday
# Processing Record 7 of Set 9 | victor harbor
# Processing Record 8 of Set 9 | the valley
# Processing Record 9 of Set 9 | boca do acre
# Processing Record 10 of Set 9 | fengxian
# Processing Record 11 of Set 9 | broken hill
# Processing Record 12 of Set 9 | paragould
# Processing Record 13 of Set 9 | vostok
# Processing Record 14 of Set 9 | hay river
# Processing Record 15 of Set 9 | fort dodge
# Processing Record 16 of Set 9 | sioux lookout
# Processing Record 17 of Set 9 | berlevag
# Processing Record 18 of Set 9 | sfantu gheorghe
# Processing Record 19 of Set 9 | fort nelson
# Processing Record 20 of Set 9 | tenenkou
# Processing Record 21 of Set 9 | takestan
# Processing Record 22 of Set 9 | hirado
# Processing Record 23 of Set 9 | camalu
# Processing Record 24 of Set 9 | longyearbyen
# Processing Record 25 of Set 9 | fare
# Processing Record 26 of Set 9 | lumsden
# Processing Record 27 of Set 9 | ahipara
# Processing Record 28 of Set 9 | coihaique
# Processing Record 29 of Set 9 | murray bridge
# Processing Record 30 of Set 9 | tagusao
# Processing Record 31 of Set 9 | conde
# Processing Record 32 of Set 9 | jinchang
# Processing Record 33 of Set 9 | awjilah
# Processing Record 34 of Set 9 | radstadt
# Processing Record 35 of Set 9 | tolaga bay
# Processing Record 36 of Set 9 | novo oriente
# Processing Record 37 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 9 | kruisfontein
# Processing Record 39 of Set 9 | shache
# Processing Record 40 of Set 9 | general roca
# Processing Record 41 of Set 9 | vila velha
# Processing Record 42 of Set 9 | taoudenni
# Processing Record 43 of Set 9 | zhuhai
# Processing Record 44 of Set 9 | tsalka
# Processing Record 45 of Set 9 | shaunavon
# Processing Record 46 of Set 9 | eqbaliyeh
# Processing Record 47 of Set 9 | tromso
# Processing Record 48 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 9 | padang
# Processing Record 50 of Set 9 | mangrol
# Processing Record 1 of Set 10 | avera
# Processing Record 2 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 10 | pulandian
# Processing Record 4 of Set 10 | kibala
# Processing Record 5 of Set 10 | yaan
# Processing Record 6 of Set 10 | manjeshwar
# Processing Record 7 of Set 10 | tarecuato
# Processing Record 8 of Set 10 | ust-omchug
# Processing Record 9 of Set 10 | port hardy
# Processing Record 10 of Set 10 | oktyabrskiy
# Processing Record 11 of Set 10 | dargaville
# Processing Record 12 of Set 10 | poya
# Processing Record 13 of Set 10 | auki
# Processing Record 14 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 15 of Set 10 | nesbyen
# Processing Record 16 of Set 10 | kamina
# Processing Record 17 of Set 10 | kolokani
# Processing Record 18 of Set 10 | korla
# Processing Record 19 of Set 10 | zhangjiakou
# Processing Record 20 of Set 10 | iguape
# Processing Record 21 of Set 10 | denpasar
# Processing Record 22 of Set 10 | bengkulu
# Processing Record 23 of Set 10 | akaszto
# Processing Record 24 of Set 10 | toora-khem
# Processing Record 25 of Set 10 | mae hong son
# Processing Record 26 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 10 | tergnier
# Processing Record 28 of Set 10 | bay roberts
# Processing Record 29 of Set 10 | havelock
# Processing Record 30 of Set 10 | tautira
# Processing Record 31 of Set 10 | emirdag
# Processing Record 32 of Set 10 | caravelas
# Processing Record 33 of Set 10 | sehithwa
# Processing Record 34 of Set 10 | hofn
# Processing Record 35 of Set 10 | maryanovka
# City not found. Skipping...
# Processing Record 36 of Set 10 | hit
# Processing Record 37 of Set 10 | lavra
# Processing Record 38 of Set 10 | beloha
# Processing Record 39 of Set 10 | mahanoro
# Processing Record 40 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 10 | hobyo
# Processing Record 42 of Set 10 | itupiranga
# Processing Record 43 of Set 10 | lorengau
# Processing Record 44 of Set 10 | poronaysk
# Processing Record 45 of Set 10 | salalah
# Processing Record 46 of Set 10 | khandyga
# Processing Record 47 of Set 10 | naze
# Processing Record 48 of Set 10 | sept-iles
# Processing Record 49 of Set 10 | manta
# Processing Record 50 of Set 10 | wajir
# Processing Record 1 of Set 11 | lokoja
# Processing Record 2 of Set 11 | las palmas
# Processing Record 3 of Set 11 | waipawa
# Processing Record 4 of Set 11 | ladario
# Processing Record 5 of Set 11 | coruripe
# Processing Record 6 of Set 11 | thompson
# Processing Record 7 of Set 11 | abomey-calavi
# Processing Record 8 of Set 11 | xghajra
# City not found. Skipping...
# Processing Record 9 of Set 11 | eyl
# Processing Record 10 of Set 11 | oussouye
# Processing Record 11 of Set 11 | finneytown
# Processing Record 12 of Set 11 | samarai
# Processing Record 13 of Set 11 | ambilobe
# Processing Record 14 of Set 11 | ixtapa
# Processing Record 15 of Set 11 | gorontalo
# Processing Record 16 of Set 11 | hami
# Processing Record 17 of Set 11 | los llanos de aridane
# Processing Record 18 of Set 11 | bayshore gardens
# Processing Record 19 of Set 11 | batemans bay
# Processing Record 20 of Set 11 | paamiut
# Processing Record 21 of Set 11 | constitucion
# Processing Record 22 of Set 11 | minot
# Processing Record 23 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 11 | tayibe
# City not found. Skipping...
# Processing Record 25 of Set 11 | dvinskoy
# Processing Record 26 of Set 11 | honningsvag
# Processing Record 27 of Set 11 | nabisar
# Processing Record 28 of Set 11 | concarneau
# Processing Record 29 of Set 11 | vao
# Processing Record 30 of Set 11 | arya
# Processing Record 31 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 32 of Set 11 | mount pleasant
# Processing Record 33 of Set 11 | byron bay
# Processing Record 34 of Set 11 | xocotla
# Processing Record 35 of Set 11 | saint-pierre
# Processing Record 36 of Set 11 | puerto madryn
# Processing Record 37 of Set 11 | jadu
# Processing Record 38 of Set 11 | smolenka
# Processing Record 39 of Set 11 | nisia floresta
# Processing Record 40 of Set 11 | sabzevar
# Processing Record 41 of Set 11 | dickinson
# Processing Record 42 of Set 11 | itaituba
# Processing Record 43 of Set 11 | shimoda
# Processing Record 44 of Set 11 | saint-augustin
# Processing Record 45 of Set 11 | seymchan
# Processing Record 46 of Set 11 | taitung
# Processing Record 47 of Set 11 | san quintin
# Processing Record 48 of Set 11 | kurilsk
# Processing Record 49 of Set 11 | bull savanna
# Processing Record 50 of Set 11 | thai binh
# Processing Record 1 of Set 12 | sorong
# Processing Record 2 of Set 12 | yichun
# Processing Record 3 of Set 12 | nalut
# Processing Record 4 of Set 12 | grafton
# Processing Record 5 of Set 12 | warmbad
# Processing Record 6 of Set 12 | gezing
# Processing Record 7 of Set 12 | boysun
# Processing Record 8 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 12 | anadyr
# Processing Record 10 of Set 12 | santa fe
# Processing Record 11 of Set 12 | tessaoua
# Processing Record 12 of Set 12 | te anau
# Processing Record 13 of Set 12 | fukue
# Processing Record 14 of Set 12 | semey
# Processing Record 15 of Set 12 | pemba
# Processing Record 16 of Set 12 | karlstad
# Processing Record 17 of Set 12 | tura
# Processing Record 18 of Set 12 | port hedland
# Processing Record 19 of Set 12 | broome
# Processing Record 20 of Set 12 | vila franca do campo
# Processing Record 21 of Set 12 | faya
# Processing Record 22 of Set 12 | san andres
# Processing Record 23 of Set 12 | lakatoro
# Processing Record 24 of Set 12 | kavieng
# Processing Record 25 of Set 12 | khani
# Processing Record 26 of Set 12 | corvallis
# Processing Record 27 of Set 12 | kourou
# Processing Record 28 of Set 12 | rawicz
# Processing Record 29 of Set 12 | dandong
# Processing Record 30 of Set 12 | ajaccio
# Processing Record 31 of Set 12 | cabedelo
# Processing Record 32 of Set 12 | belmonte
# Processing Record 33 of Set 12 | akdepe
# Processing Record 34 of Set 12 | tiarei
# Processing Record 35 of Set 12 | piacabucu
# Processing Record 36 of Set 12 | noumea
# Processing Record 37 of Set 12 | clarksville
# Processing Record 38 of Set 12 | khuzhir
# Processing Record 39 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 12 | jaru
# Processing Record 41 of Set 12 | rosolini
# Processing Record 42 of Set 12 | maniitsoq
# Processing Record 43 of Set 12 | fowa
# Processing Record 44 of Set 12 | nguruka
# Processing Record 45 of Set 12 | akureyri
# Processing Record 46 of Set 12 | pirgos
# Processing Record 47 of Set 12 | joensuu
# Processing Record 48 of Set 12 | muisne
# Processing Record 49 of Set 12 | zonguldak
# Processing Record 50 of Set 12 | muroto
# Processing Record 1 of Set 13 | alta floresta
# Processing Record 2 of Set 13 | neiafu
# Processing Record 3 of Set 13 | lompoc
# Processing Record 4 of Set 13 | juan aldama
# Processing Record 5 of Set 13 | ongandjera
# Processing Record 6 of Set 13 | sherlovaya gora
# Processing Record 7 of Set 13 | san ramon
# Processing Record 8 of Set 13 | huinan
# Processing Record 9 of Set 13 | fortuna
# Processing Record 10 of Set 13 | kaa-khem
# Processing Record 11 of Set 13 | lask
# Processing Record 12 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 13 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 14 of Set 13 | casambalangan
# Processing Record 15 of Set 13 | novhorodka
# Processing Record 16 of Set 13 | pietarsaari
# Processing Record 17 of Set 13 | asau
# Processing Record 18 of Set 13 | vaxjo
# Processing Record 19 of Set 13 | kununurra
# Processing Record 20 of Set 13 | yerbogachen
# Processing Record 21 of Set 13 | matagami
# Processing Record 22 of Set 13 | safaga
# Processing Record 23 of Set 13 | le port
# Processing Record 24 of Set 13 | athens
# Processing Record 25 of Set 13 | havre-saint-pierre
# Processing Record 26 of Set 13 | santa cruz
# Processing Record 27 of Set 13 | east wenatchee bench
# Processing Record 28 of Set 13 | hambantota
# Processing Record 29 of Set 13 | dymer
# Processing Record 30 of Set 13 | santa lucia
# Processing Record 31 of Set 13 | lucea
# Processing Record 32 of Set 13 | olive branch
# Processing Record 33 of Set 13 | vanimo
# Processing Record 34 of Set 13 | puerto leguizamo
# Processing Record 35 of Set 13 | imbituba
# Processing Record 36 of Set 13 | khilok
# Processing Record 37 of Set 13 | nigde
# Processing Record 38 of Set 13 | valparaiso
# Processing Record 39 of Set 13 | jalu
# Processing Record 40 of Set 13 | mahibadhoo
# Processing Record 41 of Set 13 | korocha
# Processing Record 42 of Set 13 | cabras
# Processing Record 43 of Set 13 | konstantinovka
# Processing Record 44 of Set 13 | mongua
# Processing Record 45 of Set 13 | udachnyy
# Processing Record 46 of Set 13 | tulun
# Processing Record 47 of Set 13 | kantang
# Processing Record 48 of Set 13 | coquimbo
# Processing Record 49 of Set 13 | dhidhdhoo
# Processing Record 50 of Set 13 | bonthe
# Processing Record 1 of Set 14 | beringovskiy
# Processing Record 2 of Set 14 | gombe
# Processing Record 3 of Set 14 | tres arroyos
# Processing Record 4 of Set 14 | sao jose da coroa grande
# Processing Record 5 of Set 14 | porto walter
# Processing Record 6 of Set 14 | krasnogorskoye
# Processing Record 7 of Set 14 | arman
# Processing Record 8 of Set 14 | marv dasht
# City not found. Skipping...
# Processing Record 9 of Set 14 | labuan
# Processing Record 10 of Set 14 | novikovo
# Processing Record 11 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 14 | sharan
# Processing Record 13 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 14 | talcahuano
# Processing Record 15 of Set 14 | lumberton
# Processing Record 16 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 14 | senneterre
# Processing Record 18 of Set 14 | kaoma
# Processing Record 19 of Set 14 | sakakah
# Processing Record 20 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 14 | abbeville
# Processing Record 22 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 14 | susangerd
# Processing Record 24 of Set 14 | mumford
# Processing Record 25 of Set 14 | shetpe
# Processing Record 26 of Set 14 | iberia
# Processing Record 27 of Set 14 | cam ranh
# Processing Record 28 of Set 14 | caluquembe
# Processing Record 29 of Set 14 | muros
# Processing Record 30 of Set 14 | bambanglipuro
# Processing Record 31 of Set 14 | lahaina
# Processing Record 32 of Set 14 | aransas pass
# Processing Record 33 of Set 14 | lazarev
# Processing Record 34 of Set 14 | mercedes
# Processing Record 35 of Set 14 | zavetnoye
# Processing Record 36 of Set 14 | santiago de cao
# Processing Record 37 of Set 14 | trapani
# Processing Record 38 of Set 14 | boone
# Processing Record 39 of Set 14 | husavik
# Processing Record 40 of Set 14 | bajil
# Processing Record 41 of Set 14 | neuquen
# Processing Record 42 of Set 14 | bella vista
# Processing Record 43 of Set 14 | palestine
# Processing Record 44 of Set 14 | ibotirama
# Processing Record 45 of Set 14 | axim
# Processing Record 46 of Set 14 | petrolina
# Processing Record 47 of Set 14 | tula
# Processing Record 48 of Set 14 | vavuniya
# Processing Record 49 of Set 14 | strezhevoy
# Processing Record 50 of Set 14 | waddan
# Processing Record 1 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 15 | ahuimanu
# Processing Record 3 of Set 15 | trelew
# Processing Record 4 of Set 15 | lagoa
# Processing Record 5 of Set 15 | stornoway
# Processing Record 6 of Set 15 | kushmurun
# Processing Record 7 of Set 15 | sabha
# Processing Record 8 of Set 15 | dubrovnik
# Processing Record 9 of Set 15 | arlit
# Processing Record 10 of Set 15 | majene
# Processing Record 11 of Set 15 | gaoua
# Processing Record 12 of Set 15 | sidi ali
# Processing Record 13 of Set 15 | kirakira
# Processing Record 14 of Set 15 | rio grande
# Processing Record 15 of Set 15 | askiz
# Processing Record 16 of Set 15 | magaria
# Processing Record 17 of Set 15 | zemio
# Processing Record 18 of Set 15 | play cu
# City not found. Skipping...
# Processing Record 19 of Set 15 | mataram
# Processing Record 20 of Set 15 | chany
# Processing Record 21 of Set 15 | gazojak
# Processing Record 22 of Set 15 | panaba
# Processing Record 23 of Set 15 | port ellen
# City not found. Skipping...
# Processing Record 24 of Set 15 | caronport
# Processing Record 25 of Set 15 | kara-tyube
# Processing Record 26 of Set 15 | rosarito
# Processing Record 27 of Set 15 | inirida
# Processing Record 28 of Set 15 | pedasi
# Processing Record 29 of Set 15 | bjelovar
# Processing Record 30 of Set 15 | labuhan
# Processing Record 31 of Set 15 | dicabisagan
# Processing Record 32 of Set 15 | maceio
# Processing Record 33 of Set 15 | pacific grove
# Processing Record 34 of Set 15 | katherine
# Processing Record 35 of Set 15 | urumqi
# Processing Record 36 of Set 15 | tianpeng
# Processing Record 37 of Set 15 | mogadishu
# Processing Record 38 of Set 15 | toledo
# Processing Record 39 of Set 15 | san vicente
# Processing Record 40 of Set 15 | phan thiet
# Processing Record 41 of Set 15 | liverpool
# Processing Record 42 of Set 15 | chelno-vershiny
# Processing Record 43 of Set 15 | coahuayana
# Processing Record 44 of Set 15 | sibiti
# Processing Record 45 of Set 15 | ilulissat
# Processing Record 46 of Set 15 | halifax
# Processing Record 47 of Set 15 | kota kinabalu
# Processing Record 48 of Set 15 | chiquiza
# City not found. Skipping...
# Processing Record 49 of Set 15 | jais
# Processing Record 50 of Set 15 | parrita
# Processing Record 1 of Set 16 | cabinda
# Processing Record 2 of Set 16 | tirodi
# Processing Record 3 of Set 16 | banamba
# Processing Record 4 of Set 16 | santa maria
# Processing Record 5 of Set 16 | pindiga
# Processing Record 6 of Set 16 | tanout
# Processing Record 7 of Set 16 | izhmorskiy
# Processing Record 8 of Set 16 | atambua
# Processing Record 9 of Set 16 | cockburn harbour
# City not found. Skipping...
# Processing Record 10 of Set 16 | solnechnyy
# Processing Record 11 of Set 16 | totma
# Processing Record 12 of Set 16 | skive
# Processing Record 13 of Set 16 | wangaratta
# Processing Record 14 of Set 16 | goulburn
# Processing Record 15 of Set 16 | guymon
# Processing Record 16 of Set 16 | tessalit
# Processing Record 17 of Set 16 | tafalla
# Processing Record 18 of Set 16 | honavar
# Processing Record 19 of Set 16 | itacare
# Processing Record 20 of Set 16 | ouesso
# Processing Record 21 of Set 16 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 16 | anupgarh
# ---------------------
# Data Retrieval Complete
# ---------------------

# %%
len(city_d)
# Out:
# 714

# %%
city_data_df = pd.DataFrame(city_d)

# %%
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    yellowknife      CA  62.4560 -114.3525     -9.00        84          20
# 1         namibe      AO -15.1961   12.1522     75.07        85          93
# 2      hithadhoo      MV  -0.6000   73.0833     83.21        68          99
# 3      fairbanks      US  64.8378 -147.7164     12.99        66           1
# 4     chokurdakh      RU  70.6333  147.9167     -9.00        93         100
# ..           ...     ...      ...       ...       ...       ...         ...
# 709      tafalla      ES  42.5269   -1.6745     48.20        87          90
# 710      honavar      IN  14.2833   74.4500     83.43        64           1
# 711      itacare      BR -14.2775  -38.9967     77.00        88          75
# 712       ouesso      CG   1.6136   16.0517     67.86        98         100
# 713     anupgarh      IN  29.1911   73.2086     78.78        22          27
#
#      Wind Speed Current Description
# 0          9.22          few clouds
# 1          3.31     overcast clouds
# 2          6.98     overcast clouds
# 3          3.44           clear sky
# 4         15.26     overcast clouds
# ..          ...                 ...
# 709       10.36     overcast clouds
# 710        3.42           clear sky
# 711       12.66       broken clouds
# 712        1.95     overcast clouds
# 713        5.06    scattered clouds
#
# [714 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
